# %%
# !pip install tensorflow

EPOCHEN = 10
# Out:
# ...
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#    ---------------------------------------- 2.1/332.0 MB 11.6 MB/s eta 0:00:29
#     --------------------------------------- 4.5/332.0 MB 11.6 MB/s eta 0:00:29
#     --------------------------------------- 6.8/332.0 MB 11.6 MB/s eta 0:00:29
#    - -------------------------------------- 9.2/332.0 MB 11.6 MB/s eta 0:00:28
#    - -------------------------------------- 11.5/332.0 MB 11.6 MB/s eta 0:00:28
#    - -------------------------------------- 14.2/332.0 MB 11.6 MB/s eta 0:00:28
#    - -------------------------------------- 16.5/332.0 MB 11.6 MB/s eta 0:00:28
#    -- ------------------------------------- 19.1/332.0 MB 11.5 MB/s eta 0:00:28
#    -- ------------------------------------- 21.5/332.0 MB 11.5 MB/s eta 0:00:27
#    -- ------------------------------------- 23.9/332.0 MB 11.5 MB/s eta 0:00:27
#    --- ------------------------------------ 26.2/332.0 MB 11.5 MB/s eta 0:00:27
# ...

# %%
import tensorflow as tf
print(tf.__version__)

# %%
# -*- coding: utf-8 -*-
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Parameter
img_rows, img_cols = 224, 224
BATCHGRÖSSE = 32
SEED_WERT = 42
EPOCHEN = 10

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

valid_generator = train_datagen.flow_from_directory(
    directory="valide",
    class_mode="binary",
    seed=SEED_WERT,
    batch_size=BATCHGRÖSSE,
    shuffle=False,
    target_size=(img_rows, img_cols)
)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    directory="Testverzeichnis",
    class_mode="binary",
    seed=SEED_WERT,
    batch_size=BATCHGRÖSSE,
    shuffle=False,
    target_size=(img_rows, img_cols)
)

# %%
model = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(img_rows, img_cols, 3)
)

# %%
history = model.fit(
    x=valid_generator,
    epochs=EPOCHEN,
    validation_data=test_generator
)

# %%
plt.figure(figsize=(5,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Genauigkeitskurve')
plt.xlabel('Epochen')
plt.ylabel('Genauigkeit')
plt.legend()
plt.show()

# %%
def test_model_on_image(test_generator, model, index):
    img, label = test_generator[index]
    pred = model.predict(img)
    plt.imshow(img[0])
    plt.title(f"Label: {label[0]}, Prediction: {pred[0]}")
    plt.show()

# Beispiel:
# test_model_on_image(test_generator, model, index=0)
